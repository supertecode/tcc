# %%
from transformers import AutoTokenizer, AutoModel, pipeline

model_name = 'unicamp-dl/mMiniLM-L6-v2-en-pt-msmarco-v2'
tokenizer  = AutoTokenizer.from_pretrained(model_name)
model      = AutoModel.from_pretrained(model_name)
# Out:
# Some weights of XLMRobertaModel were not initialized from the model checkpoint at unicamp-dl/mMiniLM-L6-v2-en-pt-msmarco-v2 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
sentiment_classifier = pipeline("text-classification", model, tokenizer)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sentiment_classifier = pipeline("text-classification", model, tokenizer)
#
# File c:\Users\super\anaconda3\envs\testetcc\Lib\site-packages\transformers\pipelines\__init__.py:1059, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1057 except Exception as e:
#    1058     if load_tokenizer:
# -> 1059         raise e
#    1060     else:
#    1061         tokenizer = None
#
# File c:\Users\super\anaconda3\envs\testetcc\Lib\site-packages\transformers\pipelines\__init__.py:1037, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1034         tokenizer = config
#    1035     else:
#    1036         # Impossible to guess what is the right tokenizer here
# -> 1037         raise Exception(
#    1038             "Impossible to guess which tokenizer to use. "
#    1039             "Please provide a PreTrainedTokenizer class or a path/identifier to a pretrained tokenizer."
#    1040         )
#    1042 # Instantiate tokenizer if needed
#    1043 if isinstance(tokenizer, (str, tuple)):
#
# Exception: Impossible to guess which tokenizer to use. Please provide a PreTrainedTokenizer class or a path/identifier to a pretrained tokenizer.
