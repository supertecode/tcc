# %%
import pandas as pd

# %%
df = pd.read_excel("amostra_sentimentos_modelonovo.xlsx")

# %%
df.head()
# Out:
#                               review_comment_message  \
# 0  Atendeu super bem todas as expectativas, são b...
# 1                     Eu ainda não recebi o produto.
# 2  Meu produto consta como entregue mais ele aind...
# 3                           Otimo site, bons preços.
# 4                     Chegou rápido e tudo em ordem!
#
#   review_comment_message_sentiment  review_comment_message_score  Predição
# 0                         Positive                      0.989328         1
# 1                          Neutral                      0.895741         1
# 2                          Neutral                      0.962915         1
# 3                         Positive                      0.992670         1
# 4                         Positive                      0.854951         1

# %%
df["Predição"].value_counts()

# %%
df.loc[df["review_comment_message_sentiment"] == "Positive", "Predição"].value_counts()
# Out:
# Predição
# 1    161
# 0      1
# Name: count, dtype: int64

# %%
df.loc[df["review_comment_message_sentiment"] == "Negative", "Predição"].value_counts()
# Out:
# Predição
# 1    57
# 0     6
# Name: count, dtype: int64

# %%
df.loc[df["review_comment_message_sentiment"] == "Neutral", "Predição"].value_counts()
# Out:
# Predição
# 1    81
# 0    74
# Name: count, dtype: int64
