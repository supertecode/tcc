# %%
import pandas as pd

# %%
df = pd.read_excel("amostra_sentimentos_rotulado.xlsx")

# %%
df["rótulo"].value_counts()
# Out:
# rótulo
# 1    272
# 0    108
# Name: count, dtype: int64

# %%
print(272/380)
# Out:
# 0.7157894736842105
