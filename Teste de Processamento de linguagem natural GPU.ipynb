# %% [markdown]
# # Teste de Processamento de linguagem natural

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Using cached transformers-4.55.4-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: filelock in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\super\appdata\roaming\python\python312\site-packages (from transformers) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (2025.7.34)
# Requirement already satisfied: requests in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: colorama in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\super\anaconda3\envs\tcc\lib\site-packages (from requests->transformers) (2025.8.3)
# Using cached transformers-4.55.4-py3-none-any.whl (11.3 MB)
# Installing collected packages: transformers
# Successfully installed transformers-4.55.4

# %%
import pandas as pd
import numpy as np
import re
import nltk
import spacy
from nltk.corpus import stopwords
from transformers import pipeline

# %%
# Download recursos
nltk.download('stopwords')
stop_words = set(stopwords.words('portuguese'))
nlp = spacy.load("pt_core_news_sm")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\super\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Pré-processamento do texto
def limpar_texto(texto):
    texto = str(texto).lower()
    texto = re.sub(r"http\S+|www\S+|https\S+", '', texto)
    texto = re.sub(r"\d+", '', texto)
    texto = re.sub(r"[^\w\s]", '', texto)
    tokens = [t for t in texto.split() if t not in stop_words]
    doc = nlp(" ".join(tokens))
    lemas = [token.lemma_ for token in doc]
    return " ".join(lemas)

# %%
# Carregar base e limpar texto
df = pd.read_csv("Data/olist_order_reviews_dataset.csv")
coluna_texto = "review_comment_message"
df = df.dropna(subset=[coluna_texto])
df['texto_limpo'] = df[coluna_texto].apply(limpar_texto)

# %%
df.head()
# Out:
#                            review_id                          order_id  \
# 3   e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4   f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 9   8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 12  4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 15  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
#
#     review_score review_comment_title  \
# 3              5                  NaN
# 4              5                  NaN
# 9              4            recomendo
# 12             4                  NaN
# 15             5      Super recomendo
#
#                                review_comment_message review_creation_date  \
# 3               Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4   Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# 9   aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n  2018-02-16 00:00:00
# 15  Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
#
#    review_answer_timestamp                                        texto_limpo
# 3      2017-04-21 22:02:06                   recebi bem antes prazo estipular
# 4      2018-03-02 10:26:53  parabéns loja lannister adorar comprar Interne...
# 9      2018-05-23 16:45:47  aparelho eficiente site marca aparelho impress...
# 12     2018-02-20 10:52:22                    pouco travandopelo valor ta bom
# 15     2018-05-24 03:00:01  vendedor confiável produto ok entregar antes p...

# %%
# Pipeline de classificação de emoções/sentimentos
classifier = pipeline(
    "text-classification",
    model="pltoledo/my_awesome_model",
    tokenizer="pltoledo/my_awesome_model",
    top_k=None,
    device=-1
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\super\anaconda3\envs\tcc\Lib\site-packages\transformers\utils\import_utils.py:2292, in __getattr__(self, name)
#    2290             raise ValueError(f"Backend should be defined in the BACKENDS_MAPPING. Offending backend: {backend}")
# -> 2292 def inner_fn(fun):
#    2293     fun.__backends = applied_backends
#
# File c:\Users\super\anaconda3\envs\tcc\Lib\site-packages\transformers\utils\import_utils.py:2322, in _get_module(self, module_name)
#    2321     if line.startswith("__all__"):
# -> 2322         start_index = index
#    2324 # There is no line starting with `__all__`
#
# File c:\Users\super\anaconda3\envs\tcc\Lib\site-packages\transformers\utils\import_utils.py:2320, in _get_module(self, module_name)
#    2319 lines = file_content.splitlines()
# -> 2320 for index, line in enumerate(lines):
#    2321     if line.startswith("__all__"):
#
# File c:\Users\super\anaconda3\envs\tcc\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.bert.configuration_bert'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Pipeline de classificação de emoções/sentimentos
# ----> 2 classifier = pipeline(
#       3     "text-classification",
#       4     model="pltoledo/my_awesome_model",
#       5     tokenizer="pltoledo/my_awesome_model",
#       6     top_k=None,
#       7     device=-1
#       8 )
#
# File c:\Users\super\anaconda3\envs\tcc\Lib\site-packages\transformers\pipelines\__init__.py:909, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#
# File c:\Users\super\anaconda3\envs\tcc\Lib\site-packages\transformers\models\auto\configuration_auto.py:1271, in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#
# File c:\Users\super\anaconda3\envs\tcc\Lib\site-packages\transformers\models\auto\configuration_auto.py:971, in __getitem__(self, key)
#
# File c:\Users\super\anaconda3\envs\tcc\Lib\site-packages\transformers\utils\import_utils.py:2295, in __getattr__(self, name)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ModuleNotFoundError: Could not import module 'BertConfig'. Are this object's requirements defined correctly?

# %%
# Classifica e retorna emoções com scores
def classificar_emocoes(texto):
    resultados = classifier(texto)[0]
    filtradas = [(r['label'], r['score']) for r in resultados if r['score'] >= 0.5]
    return filtradas if filtradas else [(resultados[0]['label'], resultados[0]['score'])]

df['emocao_scores'] = df['texto_limpo'].apply(classificar_emocoes)

# %%
# Mapeamento das emoções para uma escala 1-5 (exemplo)
mapeamento = {
    'joy': 5,
    'love': 5,
    'surprise': 4,
    'neutral': 3,
    'sadness': 2,
    'anger': 1,
    'fear': 1,
    # Adapte conforme as emoções do modelo
}

# %%
def mapear_satisfacao(lista_emocoes):
    # Se mais de uma emoção, calcula média ponderada
    soma_peso = 0
    soma_score = 0
    for label, score in lista_emocoes:
        peso = mapeamento.get(label.lower(), 3)  # neutro padrão
        soma_peso += peso * score
        soma_score += score
    return round(soma_peso / soma_score, 2) if soma_score > 0 else 3

# %%
df['nivel_satisfacao'] = df['emocao_scores'].apply(mapear_satisfacao)

# %%
df.head(100)
# Out:
#                             review_id                          order_id  \
# 3    e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4    f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 9    8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 12   4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 15   3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# ..                                ...                               ...
# 236  c4a20a1d2d634f814cca9311edd60e99  1a558554b7f10eba1ffdd56ce469df63
# 237  81e7291e2f92b492eb0340f4406c6897  93720f5a467d2edd5e84e209e8a9a4f6
# 238  eb6d75bedecae7b3dbea11b8530637d8  00b9e0f8f588d0406a3de447eb606970
# 239  593f9b33c3a4c74e37b7b7c49f0cedc4  268762d6a983092f8632e379836806eb
# 240  a36150969fe6bd09ed011dd78aeb0189  ef1b29b591d31d57c0d7337460dd83c9
#
#      review_score review_comment_title  \
# 3               5                  NaN
# 4               5                  NaN
# 9               4            recomendo
# 12              4                  NaN
# 15              5      Super recomendo
# ..            ...                  ...
# 236             5                  NaN
# 237             4                  NaN
# 238             5                  NaN
# 239             5                  NaN
# 240             1                  NaN
#
#                                 review_comment_message review_creation_date  \
# 3                Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4    Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# 9    aparelho eficiente. no site a marca do aparelh...  2018-05-22 00:00:00
# 12     Mas um pouco ,travando...pelo valor ta Boa.\r\n  2018-02-16 00:00:00
# 15   Vendedor confiável, produto ok e entrega antes...  2018-05-23 00:00:00
# ..                                                 ...                  ...
# 236  otimo produto só nao veio manual, mas sem prob...  2018-04-21 00:00:00
# 237  Uma das peças não encaixava, estava de diâmetr...  2018-04-19 00:00:00
# 238                                 Excelente produto.  2018-02-17 00:00:00
# 239                                         Tudo certo  2017-09-07 00:00:00
# 240  Demora na entrega, detestei o atendimento e NU...  2016-11-02 00:00:00
#
#     review_answer_timestamp  \
# 3       2017-04-21 22:02:06
# 4       2018-03-02 10:26:53
# 9       2018-05-23 16:45:47
# 12      2018-02-20 10:52:22
# 15      2018-05-24 03:00:01
# ..                      ...
# 236     2018-04-24 14:26:37
# 237     2018-04-22 16:36:04
# 238     2018-02-19 16:20:08
# 239     2017-09-13 13:51:51
# 240     2016-11-03 12:04:24
#
#                                            texto_limpo  \
# 3                     recebi bem antes prazo estipular
# 4    parabéns loja lannister adorar comprar Interne...
# 9    aparelho eficiente site marca aparelho impress...
# 12                     pouco travandopelo valor ta bom
# 15   vendedor confiável produto ok entregar antes p...
# ..                                                 ...
# 236              otimo produto nao vir manual problema
# 237  peça encaixar diâmetro diferente serrar martel...
# 238                                  excelente produto
# 239                                         tudo certo
# 240  demoro entrega detestei atendimento nunca comp...
#
#                           emocao_scores  nivel_satisfacao
# 3       [(neutral, 0.7800531387329102)]               3.0
# 4          [(love, 0.6320717334747314)]               5.0
# 9       [(neutral, 0.8150433301925659)]               3.0
# 12      [(neutral, 0.3537318706512451)]               3.0
# 15      [(neutral, 0.4052439332008362)]               3.0
# ..                                  ...               ...
# 236   [(admiration, 0.749000072479248)]               3.0
# 237     [(neutral, 0.8190307021141052)]               3.0
# 238  [(admiration, 0.8036838173866272)]               3.0
# 239    [(neutral, 0.33277231454849243)]               3.0
# 240   [(admiration, 0.675910234451294)]               3.0
#
# [100 rows x 10 columns]

# %%
# Exportar uma amostra para validação manual
df.sample(100)[[coluna_texto, 'texto_limpo', 'emocao_scores', 'nivel_satisfacao']].to_csv(
    "amostra_validacao_satisfacao.csv", index=False, encoding='utf-8-sig')

# %%
print("Amostra para validação gerada: 'amostra_validacao_satisfacao.csv'")
print(df[['nivel_satisfacao']].describe())
# Out:
# Amostra para validação gerada: 'amostra_validacao_satisfacao.csv'
#        nivel_satisfacao
# count      41753.000000
# mean           3.081482
# std            0.418777
# min            1.000000
# 25%            3.000000
# 50%            3.000000
# 75%            3.000000
# max            5.000000

# %%
df['nivel_satisfacao'].value_counts()
# Out:
# nivel_satisfacao
# 3.00    39534
# 5.00     1769
# 2.00      257
# 4.00       37
# 1.00       24
# 4.02        9
# 4.13        8
# 4.01        7
# 4.06        7
# 3.89        6
# 4.04        6
# 3.91        6
# 4.05        6
# 4.07        5
# 4.09        5
# 4.08        4
# 3.95        4
# 3.84        4
# 3.96        4
# 3.97        4
# 4.14        4
# 3.93        4
# 3.99        3
# 3.85        3
# 3.90        3
# 4.11        3
# 4.12        3
# 4.10        3
# 3.92        3
# 4.03        3
# 3.88        3
# 3.87        2
# 4.17        2
# 3.98        2
# 3.94        2
# 3.66        1
# 3.83        1
# 3.86        1
# 3.82        1
# Name: count, dtype: int64

# %% [markdown]
# pip uninstall torch torchvision torchaudio -y
# pip install torch-directml transformers

# %% [markdown]
# import torch_directml
# from transformers import pipeline
#
# # Cria o device do DirectML
# dml_device = torch_directml.device()
#
# # Carrega o pipeline usando DirectML
# classifier = pipeline(
#     task="text-classification",
#     model="pltoledo/my_awesome_model",
#     tokenizer="pltoledo/my_awesome_model",
#     top_k=None,
#     device=dml_device
# )
